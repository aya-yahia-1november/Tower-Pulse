# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/Africa towers.csv')

# %%
data.head()

# %%
drop_columns=['unit','changeable','averageSignal','Continent']
data=data.drop(drop_columns,axis=1)

# %%
data.head()

# %%
data['Country'].unique()

# %%
data = data[data['Country'] == 'Egypt']

# %%
# rename column Unnamed: 0
data = data.rename(columns={'Unnamed: 0': ' ID'})

# %%
data.head()

# %%
data.shape

# %%
data.info()

# %%
data.columns = data.columns.str.strip()

# %%
data = data[data["Country"].astype(str).str.strip() == "Egypt"].reset_index(drop=True)

# ------------------------------------------------------
# 1. DERIVED KPIs
# ------------------------------------------------------

# Tower Density = number of towers / area
# --> You need area, but we simulate by grouping per city/region later

# Drop Rate (simulate: RANGE column can represent traffic or attempts)
np.random.seed(42)
data["drop_calls"] = np.random.randint(0, 50, len(data))
data["total_calls"] = data["RANGE"] + data["drop_calls"]
data["drop_rate"] = (data["drop_calls"] / data["total_calls"]) * 100

# Average Load per Tower = total_calls / tower count (per MCC/MNC area)
tower_counts = data.groupby(["MCC", "MNC"])["ID"].transform("count")
data["avg_load"] = data["total_calls"] / tower_counts

# QoE Score (0–5 scale) → composite measure
data["signal_strength"] = np.random.randint(-105, -60, len(data))
data["speed"] = np.random.uniform(1, 80, len(data))          # Mbps
data["latency"] = np.random.uniform(10, 200, len(data))      # ms

# Simple QoE formula
data["QoE"] = (
    ((data["signal_strength"] + 110) / 50) * 0.4 +  # normalize 0-1
    (data["speed"] / 80) * 0.4 +
    (1 - (data["latency"] / 200)) * 0.2
) * 5

# Coverage Gap: distance > 2 km
# Simple approximation using RANGE
data["coverage_gap"] = data["RANGE"] > 2000

# ------------------------------------------------------
# 2. CLASSIFICATIONS
# ------------------------------------------------------

# Signal Quality
def classify_signal(dBm):
    if -70 <= dBm <= -60:
        return "Excellent"
    elif -80 <= dBm < -70:
        return "Good"
    elif -90 <= dBm < -80:
        return "Fair"
    elif -100 <= dBm < -90:
        return "Poor"
    else:
        return "Very Poor"

data["signal_quality"] = data["signal_strength"].apply(classify_signal)


# Tower Status
def tower_status(dr):
    if dr < 20: return "Healthy"
    elif dr < 40: return "Warning"
    elif dr < 60: return "Critical"
    else: return "Failed"

data["tower_status"] = data["drop_rate"].apply(tower_status)


# Priority Level
def assign_priority(status):
    if "Failed" in status or "Critical" in status:
        return "P1"
    elif "Warning" in status:
        return "P2"
    else:
        return "P3"

data["priority"] = data["tower_status"].apply(assign_priority)

data.head()

# %%
data.head()
# Out:
#          ID radio  MCC  MNC    TAC    CID        LON        LAT  RANGE  SAM  \
# 0  12847759   GSM  602    3  21333  25372  31.056510  29.998215  23897   10
# 1  12847760   GSM  602    3  21362  23224  31.373520  29.839554   1000    4
# 2  12847761   GSM  602    3  22533   5031  31.160660  29.998856   1000    1
# 3  12847762   GSM  602    3  22202  40686  31.501236  30.592117   1000    1
# 4  12847763   GSM  602    3  21333  25376  31.277390  30.095673   1000    2
#
#    ...  priority  maintenance_type          created_dt          updated_dt  \
# 0  ...        P3        predictive 2016-04-03 20:25:36 2016-06-08 01:07:44
# 1  ...        P3        preventive 2016-04-04 23:50:31 2016-09-18 15:36:37
# 2  ...        P3        preventive 2016-04-03 15:05:55 2016-04-03 15:05:55
# 3  ...        P3        preventive 2016-04-03 11:11:47 2016-04-03 11:11:47
# 4  ...        P3        predictive 2016-04-03 20:25:36 2016-04-12 16:31:42
#
#                maintenance_date  labor_cost_egp  parts_cost_egp  \
# 0 2016-05-19 03:32:39.863080001            4294            4318
# 1 2016-08-08 12:27:08.767132426            3336            1206
# 2 2016-04-03 15:05:55.000000000            3868            2133
# 3 2016-04-03 11:11:47.000000000            2338            1736
# 4 2016-04-07 22:49:47.089403291            4647            1995
#
#    downtime_hours    vendor               notes
# 0             5.3       ZTE
# 1             2.8       ZTE
# 2             2.3  Ericsson
# 3             2.4    Huawei  Transmission issue
# 4             4.7       ZTE    Software upgrade
#
# [5 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53048 entries, 0 to 53047
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                53048 non-null  int64
#  1   radio             53048 non-null  object
#  2   MCC               53048 non-null  int64
#  3   MNC               53048 non-null  int64
#  4   TAC               53048 non-null  int64
#  5   CID               53048 non-null  int64
#  6   LON               53048 non-null  float64
#  7   LAT               53048 non-null  float64
#  8   RANGE             53048 non-null  int64
#  9   SAM               53048 non-null  int64
#  10  created           53048 non-null  int64
#  11  updated           53048 non-null  int64
#  12  Country           53048 non-null  object
#  13  Network           53048 non-null  object
#  14  drop_calls        53048 non-null  int64
#  15  total_calls       53048 non-null  int64
#  16  drop_rate         53048 non-null  float64
#  17  avg_load          53048 non-null  float64
#  18  signal_strength   53048 non-null  int64
#  19  speed             53048 non-null  float64
#  20  latency           53048 non-null  float64
#  21  QoE               53048 non-null  float64
#  22  coverage_gap      53048 non-null  bool
#  23  signal_quality    53048 non-null  object
#  24  tower_status      53048 non-null  object
#  25  priority          53048 non-null  object
#  26  maintenance_type  53048 non-null  object
#  27  created_dt        53048 non-null  datetime64[ns]
#  28  updated_dt        53048 non-null  datetime64[ns]
#  29  maintenance_date  53048 non-null  datetime64[ns]
#  30  labor_cost_egp    53048 non-null  int64
#  31  parts_cost_egp    53048 non-null  int64
#  32  downtime_hours    53048 non-null  float64
#  33  vendor            53048 non-null  object
#  34  notes             53048 non-null  object
# dtypes: bool(1), datetime64[ns](3), float64(8), int64(14), object(9)
# memory usage: 13.8+ MB

# %%
data['vendor'].value_counts()
# Out:
# vendor
# FiberMisr           7649
# Nokia               7628
# Ericsson            7613
# Benya               7586
# ZTE                 7558
# Huawei              7528
# Local Contractor    7486
# Name: count, dtype: int64

# %%
np.random.seed(42)

# 1. Maintenance type
maintenance_types = ["preventive", "predictive", "emergency"]
maintenance_prob = [0.60, 0.25, 0.15]
data["maintenance_type"] = np.random.choice(
    maintenance_types, size=len(data), p=maintenance_prob
)

#2 Convert created & updated to datetime
data["created_dt"] = pd.to_datetime(data["created"], unit="s")
data["updated_dt"] = pd.to_datetime(data["updated"], unit="s")

# Ensure updated >= created (just in case)
mask = data["updated_dt"] < data["created_dt"]
data.loc[mask, "updated_dt"] = data.loc[mask, "created_dt"] + pd.Timedelta(days=30)

# Maintenance type
maintenance_types = ["preventive", "predictive", "emergency"]
maintenance_prob = [0.60, 0.25, 0.15]
data["maintenance_type"] = np.random.choice(
    maintenance_types, size=len(data), p=maintenance_prob
)

def generate_maintenance_date(row):
    start = row["created_dt"]
    end = row["updated_dt"]

    # Total seconds between created and updated
    total_seconds = int((end - start).total_seconds())

    if total_seconds <= 0:
        return start  # fallback

    if row["maintenance_type"] == "preventive":
        # Preventive: close to updated (last 3–6 months)
        offset_seconds = np.random.uniform(total_seconds * 0.6, total_seconds * 1.0)

    elif row["maintenance_type"] == "predictive":
        # Predictive: middle of the lifecycle
        offset_seconds = np.random.uniform(total_seconds * 0.3, total_seconds * 0.7)

    else:  # emergency
        # Emergency: anywhere randomly
        offset_seconds = np.random.uniform(0, total_seconds)

    return start + pd.Timedelta(seconds=offset_seconds)

# Generate the maintenance date
data["maintenance_date"] = data.apply(generate_maintenance_date, axis=1)

# 3. Costs based on maintenance type
def gen_labor_cost(mt):
    if mt == "preventive": return np.random.randint(1500, 4000)
    if mt == "predictive": return np.random.randint(3000, 7000)
    return np.random.randint(5000, 15000)

def gen_parts_cost(mt):
    if mt == "preventive": return np.random.randint(500, 2500)
    if mt == "predictive": return np.random.randint(1000, 5000)
    return np.random.randint(3000, 20000)

data["labor_cost_egp"]  = data["maintenance_type"].apply(gen_labor_cost)
data["parts_cost_egp"] = data["maintenance_type"].apply(gen_parts_cost)

# 4. Downtime hours
def gen_downtime(mt):
    if mt == "preventive": return round(np.random.uniform(0.5, 3), 1)
    if mt == "predictive": return round(np.random.uniform(1, 6), 1)
    return round(np.random.uniform(4, 24), 1)

data["downtime_hours"] = data["maintenance_type"].apply(gen_downtime)

# 5. Vendors
vendors = ["Huawei", "Ericsson", "Nokia", "ZTE", "FiberMisr", "Benya", "Local Contractor"]
data["vendor"] = np.random.choice(vendors, size=len(data))

# 6. Notes
notes_list = [
    "Replaced sector antenna",
    "Battery replaced",
    "Fiber cut repaired",
    "Power system failure",
    "Software upgrade",
    "Transmission issue",
    "Cooling system maintenance",
    ""
]
data["notes"] = np.random.choice(notes_list, size=len(data), p=[0.08,0.08,0.08,0.08,0.08,0.08,0.02,0.5])

# %%
data.head()
# Out:
#          ID radio  MCC  MNC    TAC    CID        LON        LAT  RANGE  SAM  \
# 0  12847759   GSM  602    3  21333  25372  31.056510  29.998215  23897   10
# 1  12847760   GSM  602    3  21362  23224  31.373520  29.839554   1000    4
# 2  12847761   GSM  602    3  22533   5031  31.160660  29.998856   1000    1
# 3  12847762   GSM  602    3  22202  40686  31.501236  30.592117   1000    1
# 4  12847763   GSM  602    3  21333  25376  31.277390  30.095673   1000    2
#
#    ...  priority  maintenance_type          created_dt          updated_dt  \
# 0  ...        P3        predictive 2016-04-03 20:25:36 2016-06-08 01:07:44
# 1  ...        P3        preventive 2016-04-04 23:50:31 2016-09-18 15:36:37
# 2  ...        P3        preventive 2016-04-03 15:05:55 2016-04-03 15:05:55
# 3  ...        P3        preventive 2016-04-03 11:11:47 2016-04-03 11:11:47
# 4  ...        P3        predictive 2016-04-03 20:25:36 2016-04-12 16:31:42
#
#                maintenance_date  labor_cost_egp  parts_cost_egp  \
# 0 2016-05-19 03:32:39.863080001            4294            4318
# 1 2016-08-08 12:27:08.767132426            3336            1206
# 2 2016-04-03 15:05:55.000000000            3868            2133
# 3 2016-04-03 11:11:47.000000000            2338            1736
# 4 2016-04-07 22:49:47.089403291            4647            1995
#
#    downtime_hours    vendor               notes
# 0             5.3       ZTE
# 1             2.8       ZTE
# 2             2.3  Ericsson
# 3             2.4    Huawei  Transmission issue
# 4             4.7       ZTE    Software upgrade
#
# [5 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53048 entries, 0 to 53047
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                53048 non-null  int64
#  1   radio             53048 non-null  object
#  2   MCC               53048 non-null  int64
#  3   MNC               53048 non-null  int64
#  4   TAC               53048 non-null  int64
#  5   CID               53048 non-null  int64
#  6   LON               53048 non-null  float64
#  7   LAT               53048 non-null  float64
#  8   RANGE             53048 non-null  int64
#  9   SAM               53048 non-null  int64
#  10  created           53048 non-null  int64
#  11  updated           53048 non-null  int64
#  12  Country           53048 non-null  object
#  13  Network           53048 non-null  object
#  14  drop_calls        53048 non-null  int64
#  15  total_calls       53048 non-null  int64
#  16  drop_rate         53048 non-null  float64
#  17  avg_load          53048 non-null  float64
#  18  signal_strength   53048 non-null  int64
#  19  speed             53048 non-null  float64
#  20  latency           53048 non-null  float64
#  21  QoE               53048 non-null  float64
#  22  coverage_gap      53048 non-null  bool
#  23  signal_quality    53048 non-null  object
#  24  tower_status      53048 non-null  object
#  25  priority          53048 non-null  object
#  26  maintenance_type  53048 non-null  object
#  27  created_dt        53048 non-null  datetime64[ns]
#  28  updated_dt        53048 non-null  datetime64[ns]
#  29  maintenance_date  53048 non-null  datetime64[ns]
#  30  labor_cost_egp    53048 non-null  int64
#  31  parts_cost_egp    53048 non-null  int64
#  32  downtime_hours    53048 non-null  float64
#  33  vendor            53048 non-null  object
#  34  notes             53048 non-null  object
# dtypes: bool(1), datetime64[ns](3), float64(8), int64(14), object(9)
# memory usage: 13.8+ MB

# %%
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 53043     True
# 53044     True
# 53045     True
# 53046     True
# 53047     True
# Name: created, Length: 53048, dtype: bool

# %%
print(data['created'])
print(data['created_dt'])

# %%
print(data['updated'])
print(data['updated_dt'])

# %%
data['maintenance_date']

# %%
data.to_csv("FULL_telecom_dataset.csv", index=False)

# %%
data.shape
# Out:
# (53048, 35)

# %%
import numpy as np
import pandas as pd
import time

def stream_tower_updates(df, n=5):
    df = df.copy()  # protect original data

    # Select 5 random towers
    sample = df.sample(n).copy()
    now_ts = int(time.time())
    now_dt = pd.Timestamp.now()

    for i in sample.index:

        # --------------------------
        # UPDATE THE "updated" FIELD
        # --------------------------
        sample.loc[i, "updated"] = now_ts
        sample.loc[i, "updated_dt"] = now_dt

        # --------------------------
        # Dynamic KPI Changes
        # --------------------------
        sample.loc[i, "drop_calls"] = max(
            0, sample.loc[i, "drop_calls"] + np.random.randint(-2, 6)
        )
        sample.loc[i, "total_calls"] = max(
            sample.loc[i, "drop_calls"] + 1,
            sample.loc[i, "total_calls"] + np.random.randint(-10, 30)
        )
        sample.loc[i, "drop_rate"] = round(
            sample.loc[i, "drop_calls"] / sample.loc[i, "total_calls"], 4
        )

        # KPI variations
        sample.loc[i, "avg_load"] = round(
            min(1, max(0, sample.loc[i, "avg_load"] + np.random.uniform(-0.05, 0.08))), 3
        )
        sample.loc[i, "signal_strength"] = np.random.randint(-110, -40)
        sample.loc[i, "speed"] = round(np.random.uniform(2, 150), 2)
        sample.loc[i, "latency"] = round(np.random.uniform(10, 150), 2)
        sample.loc[i, "QoE"] = round(
            np.random.uniform(1, 5) - sample.loc[i, "drop_rate"] * 1.5, 2
        )

        # coverage gap
        sample.loc[i, "coverage_gap"] = sample.loc[i, "signal_strength"] < -100

        # signal quality
        if sample.loc[i, "QoE"] > 4:
            sample.loc[i, "signal_quality"] = "Excellent"
        elif sample.loc[i, "QoE"] > 3:
            sample.loc[i, "signal_quality"] = "Good"
        elif sample.loc[i, "QoE"] > 2:
            sample.loc[i, "signal_quality"] = "Fair"
        else:
            sample.loc[i, "signal_quality"] = "Poor"

        # tower status
        sample.loc[i, "tower_status"] = np.random.choice(
            ["active", "warning", "down"], p=[0.85, 0.10, 0.05]
        )

        # priority logic
        if sample.loc[i, "tower_status"] == "down":
            sample.loc[i, "priority"] = "critical"
        elif sample.loc[i, "drop_rate"] > 0.1 or sample.loc[i, "avg_load"] > 0.85:
            sample.loc[i, "priority"] = "high"
        elif sample.loc[i, "drop_rate"] > 0.05:
            sample.loc[i, "priority"] = "medium"
        else:
            sample.loc[i, "priority"] = "low"

        # Maintenance small update
        sample.loc[i, "maintenance_date"] = now_dt - pd.Timedelta(
            days=np.random.randint(1, 120)
        )

        # slight cost variations
        sample.loc[i, "labor_cost_egp"] = int(sample.loc[i, "labor_cost_egp"] * np.random.uniform(0.95, 1.1))
        sample.loc[i, "parts_cost_egp"] = int(sample.loc[i, "parts_cost_egp"] * np.random.uniform(0.9, 1.2))
        sample.loc[i, "downtime_hours"] = round(
            sample.loc[i, "downtime_hours"] * np.random.uniform(0.8, 1.2), 1
        )

        # occasional notes update
        if np.random.random() < 0.08:
            sample.loc[i, "notes"] = np.random.choice([
                "Temporary power fluctuation",
                "Minor transmission delay observed",
                "Environmental interference",
                "Cooling system alert",
                ""
            ])

    return sample

# %%
while True:
    batch = stream_tower_updates(data, n=5)
    print(batch)
    print("\n--------------------------------------\n")
    time.sleep(2)  # stream every 2 seconds
# Out:
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 35787  12883546  UMTS  602    3  19321    418462  31.302109  30.057907   1000
# 35803  12883562  UMTS  602    3  24441    471860  31.277390  29.998856   1000
# 40763  12888522  UMTS  602    3  31051    364334  31.353607  30.052414   1000
# 35743  12883502  UMTS  602    3  19321    372821  31.330948  30.046921   1000
# 9567   12857326  UMTS  602    3  32031  13348560  31.164780  30.949173   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 35787    1  ...       low        preventive 2016-06-29 18:42:19
# 35803    2  ...  critical        preventive 2016-06-30 01:07:16
# 40763    2  ...       low        predictive 2016-09-28 18:09:11
# 35743    2  ...       low        preventive 2016-06-29 03:06:51
# 9567     1  ...       low        predictive 2015-06-22 19:43:18
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 35787 2025-12-09 19:51:37.848109 2025-10-08 19:51:37.848109            3687
# 35803 2025-12-09 19:51:37.848109 2025-10-22 19:51:37.848109            3497
# 40763 2025-12-09 19:51:37.848109 2025-08-24 19:51:37.848109            6004
# 35743 2025-12-09 19:51:37.848109 2025-11-18 19:51:37.848109            2878
# 9567  2025-12-09 19:51:37.848109 2025-12-02 19:51:37.848109            3892
#
#        parts_cost_egp  downtime_hours     vendor               notes
# 35787            1180             0.8      Nokia
# 35803            2427             1.9     Huawei  Fiber cut repaired
# 40763            1227             4.0  FiberMisr  Fiber cut repaired
# 35743            2662             2.1      Benya
# 9567             3350             1.6      Nokia  Fiber cut repaired
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC     CID        LON        LAT  RANGE  \
# 42804  12890563  UMTS  602    3  27001  569951  31.343307  30.092239   1000
# 19125  12866884  UMTS  602    3  32143  732387  31.273270  30.105972   1000
# 18328  12866087  UMTS  602    3  32121  667385  31.317215  29.839554   1000
# 49933  12897692   GSM  602    3  22022   14272  31.135941  28.902969   1000
# 7220   12854979  UMTS  602    3  31071  487273  31.251297  29.994736   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 42804    1  ...       low        preventive 2016-11-04 15:33:40
# 19125    1  ...       low        predictive 2015-07-10 19:58:47
# 18328    3  ...       low        preventive 2016-03-22 17:45:38
# 49933    1  ...  critical        preventive 2017-03-08 22:27:06
# 7220     1  ...       low        preventive 2016-03-17 12:57:07
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 42804 2025-12-09 19:51:39.920808 2025-08-24 19:51:39.920808            3074
# 19125 2025-12-09 19:51:39.920808 2025-09-18 19:51:39.920808            4031
# 18328 2025-12-09 19:51:39.920808 2025-11-27 19:51:39.920808            2775
# 49933 2025-12-09 19:51:39.920808 2025-10-06 19:51:39.920808            2142
# 7220  2025-12-09 19:51:39.920808 2025-10-13 19:51:39.920808            2400
#
#        parts_cost_egp  downtime_hours            vendor  \
# 42804             949             1.5  Local Contractor
# 19125            3499             1.4             Benya
# 18328             853             2.8             Nokia
# 49933            1949             2.3  Local Contractor
# 7220              573             2.2               ZTE
#
#                             notes
# 42804            Software upgrade
# 19125
# 18328  Environmental interference
# 49933
# 7220
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 48846  12896605   GSM  602    3  22371     36634  30.027695  31.197739   1000
# 1850   12849609  UMTS  602    3  32151  14131742  31.688004  30.675888   1000
# 13644  12861403   GSM  602    3  22453     47302  31.170273  30.493240   1000
# 31706  12879465  UMTS  602    3  32263  14866550  32.928085  24.375229   1000
# 46265  12894024   GSM  602    3  21311     23425  31.252346  30.125302   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 48846    1  ...       low        preventive 2017-02-22 16:11:37
# 1850     2  ...       low        preventive 2013-05-19 18:40:42
# 13644    1  ...       low        preventive 2015-12-09 03:13:00
# 31706    2  ...       low        preventive 2016-03-31 04:30:40
# 46265    3  ...  critical         emergency 2016-12-30 20:05:38
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 48846 2025-12-09 19:51:41.998827 2025-11-19 19:51:41.998827            1658
# 1850  2025-12-09 19:51:41.998827 2025-10-17 19:51:41.998827            3042
# 13644 2025-12-09 19:51:41.998827 2025-08-15 19:51:41.998827            3323
# 31706 2025-12-09 19:51:41.998827 2025-10-15 19:51:41.998827            2165
# 46265 2025-12-09 19:51:41.998827 2025-10-13 19:51:41.998827           13870
#
#        parts_cost_egp  downtime_hours            vendor               notes
# 48846            1508             2.6  Local Contractor    Software upgrade
# 1850             1690             2.2            Huawei    Software upgrade
# 13644            2203             1.5         FiberMisr
# 31706            1846             2.0  Local Contractor  Transmission issue
# 46265            9778            20.6          Ericsson
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 1332   12849091  UMTS  602    3  31061    404607  31.288376  29.968643   1000
# 38900  12886659  UMTS  602    3  32323  15230726  31.028824  30.729446   1000
# 4765   12852524  UMTS  602    3  62336  19737491  31.418839  30.169144   1000
# 18264  12866023  UMTS  602    3  32094  13728211  29.773636  31.082382   1000
# 3481   12851240  UMTS  602    3  32212  14534323  30.853043  29.305344   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 1332     1  ...       low        predictive 2011-10-04 08:17:33
# 38900    1  ...       low        preventive 2016-08-29 14:02:12
# 4765     1  ...       low        predictive 2016-03-19 09:41:58
# 18264    1  ...       low        preventive 2015-08-19 19:05:32
# 3481     1  ...       low        preventive 2015-01-23 10:40:54
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 1332  2025-12-09 19:51:44.072151 2025-12-06 19:51:44.072151            3073
# 38900 2025-12-09 19:51:44.072151 2025-09-28 19:51:44.072151            1922
# 4765  2025-12-09 19:51:44.072151 2025-11-08 19:51:44.072151            6729
# 18264 2025-12-09 19:51:44.072151 2025-11-05 19:51:44.072151            1814
# 3481  2025-12-09 19:51:44.072151 2025-09-07 19:51:44.072151            3778
#
#        parts_cost_egp  downtime_hours  vendor                    notes
# 1332             1608             1.6   Nokia  Replaced sector antenna
# 38900            1332             1.1     ZTE     Power system failure
# 4765             2745             3.5   Benya         Battery replaced
# 18264            2366             1.1   Benya       Transmission issue
# 3481             2013             1.8   Nokia         Software upgrade
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 13910  12861669   GSM  602    3  23041      5768  31.339188  30.324326   1000
# 40999  12888758   GSM  602    3  23011     28325  31.484756  30.256348   1000
# 21438  12869197  UMTS  602    3  32231  14674736  32.248306  31.280136   1000
# 24449  12872208  UMTS  602    3  33011  19740829  31.324081  30.316086   1000
# 18945  12866704  UMTS  602    3  32143  14044740  31.237564  30.089493   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 13910    1  ...       low        preventive 2015-12-13 03:32:09
# 40999    2  ...       low        preventive 2016-10-03 16:05:52
# 21438    1  ...       low        preventive 2015-12-14 16:18:23
# 24449    1  ...       low        predictive 2015-12-17 17:32:31
# 18945    1  ...       low        preventive 2016-03-05 09:03:03
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 13910 2025-12-09 19:51:46.154177 2025-10-05 19:51:46.154177            2834
# 40999 2025-12-09 19:51:46.154177 2025-08-13 19:51:46.154177            2005
# 21438 2025-12-09 19:51:46.154177 2025-10-10 19:51:46.154177            2807
# 24449 2025-12-09 19:51:46.154177 2025-12-06 19:51:46.154177            5857
# 18945 2025-12-09 19:51:46.154177 2025-11-06 19:51:46.154177            3984
#
#        parts_cost_egp  downtime_hours            vendor               notes
# 13910            1198             2.4          Ericsson
# 40999            1692             2.7               ZTE
# 21438            2135             2.0             Nokia
# 24449            3848             5.4            Huawei
# 18945             688             2.3  Local Contractor  Transmission issue
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC     CID        LON        LAT  RANGE  \
# 8280   12856039  UMTS  602    3  31091  623605  31.414190  30.057168   1000
# 740    12848499   GSM  602    3  32042   14373  32.502365  25.512314   1000
# 14560  12862319   GSM  602    3  22535   15138  31.197739  30.004349   1000
# 47500  12895259  UMTS  602    3  31051  430597  31.324081  30.074387   1000
# 46231  12893990   GSM  602    3  21312   22982  31.244431  30.125198   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 8280    13  ...       low        preventive 2016-03-21 18:53:10
# 740      1  ...       low        predictive 2012-11-26 02:56:42
# 14560    1  ...       low         emergency 2015-12-29 04:34:19
# 47500    1  ...       low        preventive 2017-01-29 08:44:29
# 46231    1  ...       low        predictive 2016-12-30 07:21:49
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 8280  2025-12-09 19:51:48.256066 2025-10-15 19:51:48.256066            2532
# 740   2025-12-09 19:51:48.256066 2025-10-18 19:51:48.256066            4052
# 14560 2025-12-09 19:51:48.256066 2025-09-23 19:51:48.256066            7817
# 47500 2025-12-09 19:51:48.256066 2025-10-06 19:51:48.256066            4035
# 46231 2025-12-09 19:51:48.256066 2025-10-14 19:51:48.256066            6216
#
#        parts_cost_egp  downtime_hours            vendor               notes
# 8280             2319             2.0               ZTE
# 740              3919             4.5             Nokia
# 14560           16041             5.4            Huawei  Fiber cut repaired
# 47500             527             2.5  Local Contractor    Battery replaced
# 46231            3605             1.3             Nokia
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 39297  12887056   GSM  602    3  21381       345  31.291122  30.126572   1000
# 49940  12897699   GSM  602    3  21392     10765  31.413345  29.687119   1000
# 41066  12888825  UMTS  602    3  31161    349812  31.358414  30.046921   1000
# 19938  12867697  UMTS  602    3  32162  14167092  31.249924  30.052414   1000
# 35960  12883719   GSM  602    3  53586      3615  31.229324  30.024948   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 39297    1  ...       low        preventive 2016-09-03 06:26:40
# 49940    1  ...       low        preventive 2017-03-08 22:27:11
# 41066    1  ...       low        preventive 2016-10-04 14:53:34
# 19938    1  ...       low        preventive 2015-07-26 07:29:06
# 35960    1  ...       low         emergency 2016-07-02 19:38:47
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 39297 2025-12-09 19:51:50.334432 2025-10-16 19:51:50.334432            3749
# 49940 2025-12-09 19:51:50.334432 2025-08-19 19:51:50.334432            3722
# 41066 2025-12-09 19:51:50.334432 2025-09-27 19:51:50.334432            4081
# 19938 2025-12-09 19:51:50.334432 2025-09-08 19:51:50.334432            3350
# 35960 2025-12-09 19:51:50.334432 2025-11-03 19:51:50.334432           11173
#
#        parts_cost_egp  downtime_hours     vendor                    notes
# 39297            2015             3.0        ZTE
# 49940            2074             0.9   Ericsson     Power system failure
# 41066            1102             1.0      Nokia         Software upgrade
# 19938            1184             2.3  FiberMisr     Power system failure
# 35960            8581            10.8        ZTE  Replaced sector antenna
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 42923  12890682  UMTS  602    3  32295  15044777  31.197739  30.034561   1000
# 50129  12897888   GSM  602    3  21281     24775  31.324081  30.143051   1000
# 46681  12894440  UMTS  602    3  32321  15245628  31.265030  30.776138   1000
# 48473  12896232   LTE  602    3  41101    149763  31.196365  29.986496   1000
# 21393  12869152  UMTS  602    3  32221  14601194  32.917099  24.803696   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 42923    1  ...       low        preventive 2016-11-06 15:31:33
# 50129    1  ...       low        preventive 2017-03-12 20:44:07
# 46681    1  ...       low        preventive 2017-01-09 06:53:23
# 48473    1  ...  critical        preventive 2017-02-18 04:11:03
# 21393    1  ...       low        preventive 2015-04-06 17:14:43
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 42923 2025-12-09 19:51:52.420576 2025-09-16 19:51:52.420576            1981
# 50129 2025-12-09 19:51:52.420576 2025-12-07 19:51:52.420576            2802
# 46681 2025-12-09 19:51:52.420576 2025-09-25 19:51:52.420576            2002
# 48473 2025-12-09 19:51:52.420576 2025-08-25 19:51:52.420576            2964
# 21393 2025-12-09 19:51:52.420576 2025-09-17 19:51:52.420576            3474
#
#        parts_cost_egp  downtime_hours            vendor  \
# 42923             629             2.4            Huawei
# 50129            1097             2.5               ZTE
# 46681            1801             2.0          Ericsson
# 48473            2211             2.0  Local Contractor
# 21393            1551             2.8          Ericsson
#
#                          notes
# 42923
# 50129  Replaced sector antenna
# 46681       Transmission issue
# 48473
# 21393
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 37594  12885353   GSM  602    3  21262     13622  31.233444  30.070267   1000
# 48085  12895844   GSM  602    3  22121      9843  31.391373  31.050797   1000
# 46319  12894078  UMTS  602    3  32181  14300590  33.827591  27.185669   1000
# 29178  12876937   GSM  602    3  21332     21843  31.258163  30.119705   1000
# 2644   12850403   GSM  602    3  21141     29055  31.297760  30.103226   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 37594    1  ...       low        predictive 2016-08-10 07:58:01
# 48085    1  ...       low        predictive 2017-02-09 08:00:52
# 46319    2  ...       low        preventive 2016-12-31 22:06:59
# 29178    1  ...       low        preventive 2015-03-05 16:16:33
# 2644     6  ...       low        predictive 2014-01-05 17:16:54
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 37594 2025-12-09 19:51:54.497561 2025-09-03 19:51:54.497561            6821
# 48085 2025-12-09 19:51:54.497561 2025-10-22 19:51:54.497561            3218
# 46319 2025-12-09 19:51:54.497561 2025-10-11 19:51:54.497561            3399
# 29178 2025-12-09 19:51:54.497561 2025-09-30 19:51:54.497561            1868
# 2644  2025-12-09 19:51:54.497561 2025-10-10 19:51:54.497561            5399
#
#        parts_cost_egp  downtime_hours     vendor                 notes
# 37594            1266             1.4   Ericsson
# 48085            1685             2.7  FiberMisr
# 46319             850             2.4     Huawei      Software upgrade
# 29178            1220             3.1      Benya    Transmission issue
# 2644             3578             2.4     Huawei  Power system failure
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 20424  12868183  UMTS  602    3  32181  14352367  33.663827  27.406431   6000
# 29926  12877685   GSM  602    3  22062     36696  28.718948  30.978012   1000
# 6465   12854224  UMTS  602    3  31051    537295  31.344681  30.105972   1000
# 40826  12888585  UMTS  602    3  31161   1052350  31.388098  30.110620   1000
# 29853  12877612   GSM  602    3  22112     41184  31.221085  30.752792   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 20424    4  ...       low        preventive 2016-03-22 17:45:57
# 29926    1  ...       low        preventive 2015-08-02 04:17:18
# 6465     1  ...       low        preventive 2015-10-20 16:40:08
# 40826   13  ...       low        predictive 2016-09-30 14:36:56
# 29853    1  ...       low        preventive 2015-07-02 22:33:34
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 20424 2025-12-09 19:51:56.573517 2025-09-14 19:51:56.573517            1837
# 29926 2025-12-09 19:51:56.573517 2025-08-17 19:51:56.573517            1895
# 6465  2025-12-09 19:51:56.573517 2025-09-01 19:51:56.573517            3361
# 40826 2025-12-09 19:51:56.573517 2025-12-02 19:51:56.573517            3713
# 29853 2025-12-09 19:51:56.573517 2025-10-27 19:51:56.573517            2507
#
#        parts_cost_egp  downtime_hours    vendor                    notes
# 20424            1166             1.5  Ericsson         Battery replaced
# 29926            2505             1.1    Huawei  Replaced sector antenna
# 6465             2156             0.7    Huawei
# 40826            4647             4.4     Benya     Power system failure
# 29853            2106             3.0  Ericsson
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 49499  12897258   GSM  602    3  22548      7235  31.011887  30.231400   1000
# 11082  12858841   GSM  602    3  22211     14307  31.492996  31.383133   1000
# 25122  12872881   GSM  602    3  21131     20803  31.222458  30.016708   1000
# 36601  12884360   GSM  602    3  22531     30801  31.068237  29.958027   2093
# 19262  12867021  UMTS  602    3  32152  14117281  31.445195  31.051166   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 49499    3  ...       low        preventive 2017-03-03 15:16:52
# 11082    1  ...       low        preventive 2015-08-05 11:04:18
# 25122    1  ...       low        predictive 2015-09-19 10:02:07
# 36601    7  ...       low         emergency 2016-07-17 08:47:27
# 19262   26  ...       low        preventive 2016-03-22 17:45:49
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 49499 2025-12-09 19:51:58.654902 2025-12-08 19:51:58.654902            3778
# 11082 2025-12-09 19:51:58.654902 2025-09-14 19:51:58.654902            2885
# 25122 2025-12-09 19:51:58.654902 2025-11-06 19:51:58.654902            5430
# 36601 2025-12-09 19:51:58.654902 2025-09-05 19:51:58.654902           10469
# 19262 2025-12-09 19:51:58.654902 2025-11-05 19:51:58.654902            4198
#
#        parts_cost_egp  downtime_hours            vendor  \
# 49499             666             1.5            Huawei
# 11082            1256             1.2  Local Contractor
# 25122            3000             2.4          Ericsson
# 36601           17502            19.1             Nokia
# 19262            1165             1.5  Local Contractor
#
#                          notes
# 49499
# 11082         Software upgrade
# 25122         Battery replaced
# 36601
# 19262  Replaced sector antenna
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 16494  12864253  UMTS  602    3  32086  13645234  30.861282  30.138245   1000
# 40171  12887930   GSM  602    3  22071     52926  32.722092  26.167374   1000
# 11916  12859675   GSM  602    3  22301     46613  31.029510  30.705414   1000
# 18830  12866589  UMTS  602    3  32151  14131397  31.370773  31.037064   1000
# 26831  12874590   GSM  602    3  21211     35772  31.207352  30.052414   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 16494    2  ...       low         emergency 2016-03-22 17:45:30
# 40171    1  ...       low        preventive 2016-09-14 19:23:53
# 11916    2  ...       low        predictive 2016-03-22 00:15:16
# 18830    1  ...       low        preventive 2015-05-21 02:08:48
# 26831    1  ...       low        preventive 2015-01-30 13:25:41
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 16494 2025-12-09 19:52:00.749991 2025-10-03 19:52:00.749991           11961
# 40171 2025-12-09 19:52:00.749991 2025-11-28 19:52:00.749991            2904
# 11916 2025-12-09 19:52:00.749991 2025-10-11 19:52:00.749991            3099
# 18830 2025-12-09 19:52:00.749991 2025-10-13 19:52:00.749991            3214
# 26831 2025-12-09 19:52:00.749991 2025-09-03 19:52:00.749991            1855
#
#        parts_cost_egp  downtime_hours            vendor  \
# 16494            7663            17.0  Local Contractor
# 40171            2120             2.1            Huawei
# 11916            3864             5.1  Local Contractor
# 18830             522             2.4          Ericsson
# 26831            1979             0.4            Huawei
#
#                          notes
# 16494  Replaced sector antenna
# 40171
# 11916         Battery replaced
# 18830         Software upgrade
# 26831
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 47648  12895407  UMTS  602    3  32281  14980095  30.002975  31.263657   1000
# 37213  12884972  UMTS  602    3  31171   1140628  31.226578  30.018082   1000
# 24194  12871953  UMTS  602    3  32281  14980835  29.997482  31.254044   1000
# 41995  12889754   GSM  602    3  22352     54806  31.188126  27.186356   1000
# 13379  12861138   GSM  602    3  22451     26536  30.927200  30.474014   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 47648    1  ...       low        preventive 2017-02-01 19:02:33
# 37213    3  ...       low        preventive 2016-08-01 02:50:38
# 24194    2  ...       low        predictive 2016-03-22 17:46:13
# 41995    1  ...       low        preventive 2016-10-18 13:00:05
# 13379    1  ...       low         emergency 2015-02-24 01:20:54
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 47648 2025-12-09 19:52:02.845925 2025-11-29 19:52:02.845925            2557
# 37213 2025-12-09 19:52:02.845925 2025-08-18 19:52:02.845925            3262
# 24194 2025-12-09 19:52:02.845925 2025-11-11 19:52:02.845925            5995
# 41995 2025-12-09 19:52:02.845925 2025-11-15 19:52:02.845925            2761
# 13379 2025-12-09 19:52:02.845925 2025-08-18 19:52:02.845925           12310
#
#        parts_cost_egp  downtime_hours  vendor                 notes
# 47648            1799             2.5  Huawei    Fiber cut repaired
# 37213            2203             1.5   Benya      Software upgrade
# 24194            4299             2.0     ZTE  Power system failure
# 41995             973             2.1   Nokia
# 13379            6222             6.1     ZTE      Software upgrade
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 45060  12892819  UMTS  602    3  32094  13728360  29.794922  31.019211   1000
# 2452   12850211  UMTS  602    3  31061   2868706  31.204880  29.990891   1000
# 52142  12899901  UMTS  602    3  32131  14009849  31.465017  26.860500   1000
# 50979  12898738  UMTS  602    3  32244  14718477  31.160660  29.991989   1000
# 39844  12887603   GSM  602    3  21192     12161  31.269150  29.990616   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 45060    2  ...       low        preventive 2016-12-04 21:07:44
# 2452     5  ...  critical         emergency 2013-11-29 11:19:01
# 52142    1  ...       low        predictive 2017-09-19 16:11:38
# 50979    1  ...       low        preventive 2017-03-27 15:31:36
# 39844    2  ...       low         emergency 2016-09-13 15:55:16
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 45060 2025-12-09 19:52:04.936533 2025-08-18 19:52:04.936533            1956
# 2452  2025-12-09 19:52:04.936533 2025-11-08 19:52:04.936533           13412
# 52142 2025-12-09 19:52:04.936533 2025-10-27 19:52:04.936533            3544
# 50979 2025-12-09 19:52:04.936533 2025-10-13 19:52:04.936533            4133
# 39844 2025-12-09 19:52:04.936533 2025-10-28 19:52:04.936533            9799
#
#        parts_cost_egp  downtime_hours     vendor                    notes
# 45060             828             3.4  FiberMisr  Replaced sector antenna
# 2452            19484             7.2     Huawei         Software upgrade
# 52142            2590             1.6   Ericsson
# 50979            2417             1.9      Benya         Software upgrade
# 39844           13716             7.3      Nokia     Power system failure
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 23618  12871377  UMTS  602    3  32264  14866713  32.910233  24.081345   1000
# 28058  12875817   GSM  602    3  21321       524  31.394119  30.114212   1000
# 39032  12886791  UMTS  602    3  32245  14709050  31.121383  29.996207   1000
# 7304   12855063  UMTS  602    3  31081    546595  31.307945  30.090523   1000
# 23     12847782  UMTS  602    3  32086  13659339  30.950546  30.078506   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 23618    1  ...       low         emergency 2016-01-09 09:20:52
# 28058    1  ...       low        preventive 2016-01-11 17:52:21
# 39032    3  ...       low        preventive 2016-09-01 09:07:45
# 7304     4  ...       low        preventive 2016-03-21 18:53:02
# 23       7  ...       low        predictive 2012-11-28 12:31:52
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 23618 2025-12-09 19:52:07.024833 2025-11-04 19:52:07.024833           15451
# 28058 2025-12-09 19:52:07.024833 2025-10-07 19:52:07.024833            2476
# 39032 2025-12-09 19:52:07.024833 2025-08-27 19:52:07.024833            3239
# 7304  2025-12-09 19:52:07.024833 2025-09-24 19:52:07.024833            2730
# 23    2025-12-09 19:52:07.024833 2025-09-10 19:52:07.024833            6965
#
#        parts_cost_egp  downtime_hours     vendor                    notes
# 23618           12143             8.0      Benya     Power system failure
# 28058            1300             1.2        ZTE
# 39032            1466             1.8      Benya         Battery replaced
# 7304             1275             2.4   Ericsson
# 23               2483             4.1  FiberMisr  Replaced sector antenna
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 27584  12875343   GSM  602    3  21261      3681  31.239624  30.090179   1000
# 23852  12871611  UMTS  602    3  32292  15021180  31.045303  30.075760   1000
# 40288  12888047  UMTS  602    3  50041   1138373  31.218338  30.016708   1000
# 31602  12879361   GSM  602    3  22071     57538  32.724838  26.159134   1000
# 51097  12898856  UMTS  602    3  32153  14103571  31.937943  26.244278   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 27584    2  ...       low        preventive 2016-03-25 10:45:38
# 23852    1  ...       low        preventive 2015-12-17 04:51:53
# 40288    1  ...       low        preventive 2016-09-16 07:45:57
# 31602    3  ...       low        preventive 2016-03-30 01:08:16
# 51097    1  ...       low        predictive 2017-03-28 16:19:24
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 27584 2025-12-09 19:52:09.116800 2025-10-30 19:52:09.116800            2848
# 23852 2025-12-09 19:52:09.116800 2025-09-12 19:52:09.116800            2681
# 40288 2025-12-09 19:52:09.116800 2025-11-24 19:52:09.116800            2476
# 31602 2025-12-09 19:52:09.116800 2025-12-03 19:52:09.116800            3266
# 51097 2025-12-09 19:52:09.116800 2025-08-23 19:52:09.116800            4169
#
#        parts_cost_egp  downtime_hours            vendor             notes
# 27584            1449             2.1  Local Contractor
# 23852            2066             0.8  Local Contractor
# 40288            2114             1.0         FiberMisr  Software upgrade
# 31602            2356             1.5         FiberMisr
# 51097            1144             5.9          Ericsson
#
# [5 rows x 35 columns]
#
# --------------------------------------
#
#              ID radio  MCC  MNC    TAC       CID        LON        LAT  RANGE  \
# 52677  12900436  UMTS  602    3  32162  14161292  31.238491  30.044794   1000
# 16307  12864066  UMTS  602    3  32083  13695740  30.993118  29.994736   1000
# 26301  12874060   GSM  602    3  21191     26322  31.258163  29.975510   1000
# 49437  12897196  UMTS  602    3  34681    734422  31.219711  30.214462   1000
# 10133  12857892  UMTS  602    3  32032  13307445  30.760345  30.548172   1000
#
#        SAM  ...  priority  maintenance_type          created_dt  \
# 52677    1  ...       low        preventive 2017-04-18 18:30:00
# 16307    1  ...       low        preventive 2015-11-13 04:03:29
# 26301    1  ...       low        preventive 2016-01-05 11:43:19
# 49437    1  ...  critical        preventive 2017-03-03 05:33:59
# 10133    4  ...       low        preventive 2016-03-21 18:53:20
#
#                       updated_dt           maintenance_date  labor_cost_egp  \
# 52677 2025-12-09 19:52:11.216202 2025-10-09 19:52:11.216202            2782
# 16307 2025-12-09 19:52:11.216202 2025-08-15 19:52:11.216202            2178
# 26301 2025-12-09 19:52:11.216202 2025-09-20 19:52:11.216202            3844
# 49437 2025-12-09 19:52:11.216202 2025-09-21 19:52:11.216202            3483
# 10133 2025-12-09 19:52:11.216202 2025-09-06 19:52:11.216202            2443
#
#        parts_cost_egp  downtime_hours     vendor                    notes
# 52677            1893             2.7   Ericsson
# 16307            2254             1.3      Benya     Power system failure
# 26301            2294             2.3     Huawei
# 49437            1609             2.5        ZTE
# 10133            1062             2.3  FiberMisr  Replaced sector antenna
#
# [5 rows x 35 columns]
#
# --------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2039002979.py in <cell line: 0>()
#       3     print(batch)
#       4     print("\n--------------------------------------\n")
# ----> 5     time.sleep(2)  # stream every 2 seconds
#
# KeyboardInterrupt:
